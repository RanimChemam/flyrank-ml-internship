# %% [markdown]
# <a href="https://colab.research.google.com/github/RanimChemam/flyrank-ml-internship/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/RanimChemam/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane and why
#
# I chose the Refresh / Content Opportunity Scoring lane.
#
# My goal is to investigate whether available content and search performance signals can help prioritize which pages should be reviewed first by an SEO or content specialist. I chose this lane because the dataset contains page-level signals related to search demand, traffic, engagement, content age, freshness, and recent trends. This is a provisional choice, and I may refine the question as I learn more about the data.

# %%
import os

print(os.listdir("/content/flyrank-ml-internship"))
# Out:
# ['DATA_USE.md', 'README.md', 'notebooks', 'docs', 'work', 'SETUP.md', 'data', 'scripts', 'skills', 'outputs', '.git', 'AGENTS.md', 'LICENSE', '.github', 'submission', 'CLAUDE.md', 'GUIDE.md', '.gitignore', 'requirements.txt']

# %%
print(os.listdir("/content/flyrank-ml-internship/data/raw"))
# Out:
# ['content_refresh_anonymized.csv']

# %%
import pandas as pd

df = pd.read_csv(
    "/content/flyrank-ml-internship/data/raw/content_refresh_anonymized.csv"
)

print("Rows:", len(df))
print("Columns:", len(df.columns))
print(df.columns.tolist())
# Out:
# Rows: 30000
# Columns: 44
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# ### Decision
# Which content pages should an SEO or content specialist review first?
#
# ### Action
# The specialist reviews the highest-priority pages and decides whether they need a content update, further investigation, or no action.
#
# ### Cost of a wrong recommendation
# A false positive could waste the specialist's time on a page that does not need attention. A false negative could cause an important page to be overlooked.
#
# ### Why data or ML can help
# The dataset contains multiple signals about search demand, traffic, engagement, content age, freshness, and recent trends. Combining these signals may help create a more useful priority ranking than relying on a single rule.

# %%
print("Decision: prioritize content pages for human review")
print("Unit of analysis: one content item/page")
print("Action: human SEO/content review")
print("Wrong-call cost: wasted review time or missed opportunities")
# Out:
# Decision: prioritize content pages for human review
# Unit of analysis: one content item/page
# Action: human SEO/content review
# Wrong-call cost: wasted review time or missed opportunities

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The starter dataset contains 30,000 content items and 44 columns. It includes signals related to search demand, traffic, engagement, content age, freshness, and recent trends. This makes the Refresh / Content Opportunity Scoring lane worth investigating because there are multiple observable signals that could support a page-prioritization decision.

# %%
print("Number of content items:", df["content_id"].nunique())
print("Number of clients:", df["client_id"].nunique())
print("Average impressions over 90 days:", round(df["impressions_90d"].mean(), 2))
# Out:
# Number of content items: 30000
# Number of clients: 32
# Average impressions over 90 days: 5200.37

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# ### What I can claim
#
# I can describe observed patterns in the starter data and investigate whether the available signals are useful for prioritizing content pages for human review. The results can provide directional evidence and decision-support.
#
# ### What I can't claim
#
# I cannot claim that the analysis proves that updating a page will cause better performance. I cannot claim that the model predicts Google rankings or future search behavior. The starter data is observational, and any future model should be evaluated carefully before being used for decisions.

# %%
print("Claims are limited to observed, measured, directional, and decision-support findings.")
print("No causal claims and no claim of predicting Google rankings.")
# Out:
# Claims are limited to observed, measured, directional, and decision-support findings.
# No causal claims and no claim of predicting Google rankings.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
